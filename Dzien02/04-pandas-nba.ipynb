# %%
import pandas as pd

# %%
df = pd.read_csv("http://51.91.120.89/extras/nba.csv", index_col="Name")
df
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
df.isna().sum()
# Out:
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
df.dropna(axis=0, how="all", inplace=True)

# %%
df.tail()
# Out:
#                    Team  Number Position   Age Height  Weight   College  \
# Name
# Trey Lyles    Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# Raul Neto     Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# Jeff Withey   Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#                  Salary
# Name
# Trey Lyles    2239800.0
# Shelvin Mack  2433333.0
# Raul Neto      900000.0
# Tibor Pleiss  2900000.0
# Jeff Withey    947276.0

# %%
df.dtypes
# Out:
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
# wypełnianie NaN
df.College.fillna("", inplace=True)

# %%
df.College.isna().sum()
# Out:
# 0

# %%
# konwersja pounds -> kg
df.Weight /= 2.2

# %%
def convert_height(s):
    # 6-2
    feet, inches = s.split("-")
    return int(feet)*30.4 + int(inches)*2.54

#convert_height("6-10")

df.Height = df.Height.apply(convert_height)

# %%
df.sort_values(["Age","Height"], ascending=[False, True])
# Out:
#                                       Team  Number Position   Age  Height  \
# Name
# Andre Miller             San Antonio Spurs    24.0       PG  40.0  190.02
# Tim Duncan               San Antonio Spurs    21.0        C  40.0  210.34
# Kevin Garnett       Minnesota Timberwolves    21.0       PF  40.0  210.34
# Pablo Prigioni        Los Angeles Clippers     9.0       PG  39.0  190.02
# Vince Carter             Memphis Grizzlies    15.0       SG  39.0  197.64
# ...                                    ...     ...      ...   ...     ...
# Myles Turner                Indiana Pacers    33.0       PF  20.0  210.34
# Karl-Anthony Towns  Minnesota Timberwolves    32.0        C  20.0  212.80
# Kristaps Porzingis         New York Knicks     6.0       PF  20.0  220.42
# Devin Booker                  Phoenix Suns     1.0       SG  19.0  197.64
# Rashad Vaughn              Milwaukee Bucks    20.0       SG  19.0  197.64
#
#                         Weight         College     Salary
# Name
# ...

# %%
df.nlargest(10, "Age")
# Out:
#                                   Team  Number Position   Age  Height  \
# Name
# Tim Duncan           San Antonio Spurs    21.0        C  40.0  210.34
# Andre Miller         San Antonio Spurs    24.0       PG  40.0  190.02
# Kevin Garnett   Minnesota Timberwolves    21.0       PF  40.0  210.34
# Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0  190.02
# Vince Carter         Memphis Grizzlies    15.0       SG  39.0  197.64
# Paul Pierce       Los Angeles Clippers    34.0       SF  38.0  200.18
# Jason Terry            Houston Rockets    31.0       SG  38.0  187.48
# Manu Ginobili        San Antonio Spurs    20.0       SG  38.0  197.64
# Nazr Mohammed    Oklahoma City Thunder    13.0        C  38.0  207.80
# Elton Brand         Philadelphia 76ers    42.0       PF  37.0  205.26
#
#                     Weight         College     Salary
# Name
# Tim Duncan      113.636364     Wake Forest  5250000.0
# Andre Miller     90.909091            Utah   250750.0
# ...

# %%
df.nsmallest(10, "Height")
# Out:
#                                  Team  Number Position   Age  Height  \
# Name
# Isaiah Thomas          Boston Celtics     4.0       PG  27.0  174.86
# Shane Larkin            Brooklyn Nets     0.0       PG  23.0  179.94
# Phil Pressey             Phoenix Suns    25.0       PG  25.0  179.94
# Ty Lawson              Indiana Pacers    10.0       PG  28.0  179.94
# Isaiah Canaan      Philadelphia 76ers     0.0       PG  25.0  182.40
# Ish Smith          Philadelphia 76ers     1.0       PG  27.0  182.40
# Kyle Lowry            Toronto Raptors     7.0       PG  30.0  182.40
# Chris Paul       Los Angeles Clippers     3.0       PG  31.0  182.40
# Darren Collison      Sacramento Kings     7.0       PG  28.0  182.40
# Aaron Brooks            Chicago Bulls     0.0       PG  31.0  182.40
#
#                     Weight         College      Salary
# Name
# Isaiah Thomas    84.090909      Washington   6912869.0
# Shane Larkin     79.545455      Miami (FL)   1500000.0
# ...

# %%
# filtrowanie: wyżsi niż 200cm
df[ df.Height > 200 ].sort_values('Height')
# Out:
#                                     Team  Number Position   Age  Height  \
# Name
# Caron Butler            Sacramento Kings    31.0       SF  36.0  200.18
# Solomon Hill              Indiana Pacers    44.0       SF  25.0  200.18
# Justise Winslow               Miami Heat    20.0       SF  20.0  200.18
# Stanley Johnson          Detroit Pistons     3.0       SF  20.0  200.18
# Paul Pierce         Los Angeles Clippers    34.0       SF  38.0  200.18
# ...                                  ...     ...      ...   ...     ...
# Alexis Ajinca       New Orleans Pelicans    42.0        C  28.0  217.88
# Walter Tavares             Atlanta Hawks    22.0        C  24.0  220.42
# Tibor Pleiss                   Utah Jazz    21.0        C  26.0  220.42
# Boban Marjanovic       San Antonio Spurs    40.0        C  27.0  220.42
# Kristaps Porzingis       New York Knicks     6.0       PF  20.0  220.42
#
#                         Weight      College     Salary
# Name
# ...

# %%
# filtrowanie: wyżsi niż 200cm i Salary>1mln i Age<25
df[ (df.Height > 200)&(df.Salary > 1E6)&(df.Age<25) ].sort_values(['Height','Salary','Age'])
# Out:
#                                            Team  Number Position   Age  \
# Name
# Glenn Robinson III               Indiana Pacers    40.0       SG  22.0
# Josh Huestis              Oklahoma City Thunder    34.0       SF  24.0
# Andre Roberson            Oklahoma City Thunder    21.0       SG  24.0
# Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# Tony Snell                        Chicago Bulls    20.0       SF  24.0
# ...                                         ...     ...      ...   ...
# Karl-Anthony Towns       Minnesota Timberwolves    32.0        C  20.0
# Rudy Gobert                           Utah Jazz    27.0        C  23.0
# Meyers Leonard           Portland Trail Blazers    11.0       PF  24.0
# Alex Len                           Phoenix Suns    21.0        C  22.0
# Kristaps Porzingis              New York Knicks     6.0       PF  20.0
#
#                          Height      Weight     College     Salary
# Name
# ...

# %%
df.loc[ ["John Holland"] ]
# Out:
#                         Team  Number Position   Age  Height     Weight  \
# Name
# John Holland  Boston Celtics    30.0       SG  27.0   195.1  93.181818
#
#                         College  Salary
# Name
# John Holland  Boston University     NaN

# %%
df.loc[ ["John Holland","Alex Len","Andre Roberson"] ]
# Out:
#                                  Team  Number Position   Age  Height  \
# Name
# John Holland           Boston Celtics    30.0       SG  27.0  195.10
# Alex Len                 Phoenix Suns    21.0        C  22.0  215.34
# Andre Roberson  Oklahoma City Thunder    21.0       SG  24.0  200.18
#
#                     Weight            College     Salary
# Name
# John Holland     93.181818  Boston University        NaN
# Alex Len        118.181818           Maryland  3807120.0
# Andre Roberson   95.454545           Colorado  1210800.0

# %%
df.loc["Jae Crowder":"Jonas Jerebko" , "Position":]
# Out:
#               Position   Age  Height      Weight            College     Salary
# Name
# Jae Crowder         SF  25.0  197.64  106.818182          Marquette  6796117.0
# John Holland        SG  27.0  195.10   93.181818  Boston University        NaN
# R.J. Hunter         SG  22.0  195.10   84.090909      Georgia State  1148640.0
# Jonas Jerebko       PF  29.0  207.80  105.000000                     5000000.0

# %%
df.loc["Jae Crowder":"Jonas Jerebko", ["Number","Weight","Salary"] ]
# Out:
#                Number      Weight     Salary
# Name
# Jae Crowder      99.0  106.818182  6796117.0
# John Holland     30.0   93.181818        NaN
# R.J. Hunter      28.0   84.090909  1148640.0
# Jonas Jerebko     8.0  105.000000  5000000.0

# %%
df.loc["Jae Crowder":"Jonas Jerebko", ::-1 ]
# Out:
#                   Salary            College      Weight  Height   Age  \
# Name
# Jae Crowder    6796117.0          Marquette  106.818182  197.64  25.0
# John Holland         NaN  Boston University   93.181818  195.10  27.0
# R.J. Hunter    1148640.0      Georgia State   84.090909  195.10  22.0
# Jonas Jerebko  5000000.0                     105.000000  207.80  29.0
#
#               Position  Number            Team
# Name
# Jae Crowder         SF    99.0  Boston Celtics
# John Holland        SG    30.0  Boston Celtics
# R.J. Hunter         SG    28.0  Boston Celtics
# Jonas Jerebko       PF     8.0  Boston Celtics

# %%
df.loc[ : , "Age":]
# Out:
#                 Age  Height      Weight            College     Salary
# Name
# Avery Bradley  25.0  187.48   81.818182              Texas  7730337.0
# Jae Crowder    25.0  197.64  106.818182          Marquette  6796117.0
# John Holland   27.0  195.10   93.181818  Boston University        NaN
# R.J. Hunter    22.0  195.10   84.090909      Georgia State  1148640.0
# Jonas Jerebko  29.0  207.80  105.000000                     5000000.0
# ...             ...     ...         ...                ...        ...
# Trey Lyles     20.0  207.80  106.363636           Kentucky  2239800.0
# Shelvin Mack   26.0  190.02   92.272727             Butler  2433333.0
# Raul Neto      24.0  184.94   81.363636                      900000.0
# Tibor Pleiss   26.0  220.42  116.363636                     2900000.0
# Jeff Withey    26.0  212.80  105.000000             Kansas   947276.0
#
# [457 rows x 5 columns]

# %%
df.iloc[ :10 , 3: ]
# Out:
#                 Age  Height      Weight            College      Salary
# Name
# Avery Bradley  25.0  187.48   81.818182              Texas   7730337.0
# Jae Crowder    25.0  197.64  106.818182          Marquette   6796117.0
# John Holland   27.0  195.10   93.181818  Boston University         NaN
# R.J. Hunter    22.0  195.10   84.090909      Georgia State   1148640.0
# Jonas Jerebko  29.0  207.80  105.000000                      5000000.0
# Amir Johnson   29.0  205.26  109.090909                     12000000.0
# Jordan Mickey  21.0  202.72  106.818182                LSU   1170960.0
# Kelly Olynyk   25.0  212.80  108.181818            Gonzaga   2165160.0
# Terry Rozier   22.0  187.48   86.363636         Louisville   1824360.0
# Marcus Smart   22.0  192.56  100.000000     Oklahoma State   3431040.0

# %%
df.iloc[ ::3 ,[0,-2,-1] ]
# Out:
#                          Team         College     Salary
# Name
# Avery Bradley  Boston Celtics           Texas  7730337.0
# R.J. Hunter    Boston Celtics   Georgia State  1148640.0
# Jordan Mickey  Boston Celtics             LSU  1170960.0
# Marcus Smart   Boston Celtics  Oklahoma State  3431040.0
# Evan Turner    Boston Celtics      Ohio State  3425510.0
# ...                       ...             ...        ...
# Alec Burks          Utah Jazz        Colorado  9463484.0
# Rudy Gobert         Utah Jazz                  1175880.0
# Joe Ingles          Utah Jazz                  2050000.0
# Shelvin Mack        Utah Jazz          Butler  2433333.0
# Jeff Withey         Utah Jazz          Kansas   947276.0
#
# [153 rows x 3 columns]

# %%
df.query(" Height>200 and (Age<25 or Age>35) and Position in ['C','SG'] ")
# Out:
#                                            Team  Number Position   Age  \
# Name
# Jared Sullinger                  Boston Celtics     7.0        C  24.0
# Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# Sergey Karasev                    Brooklyn Nets    10.0       SG  22.0
# Joel Embiid                  Philadelphia 76ers    21.0        C  22.0
# Jahlil Okafor                Philadelphia 76ers     8.0        C  20.0
# Bismack Biyombo                 Toronto Raptors     8.0        C  23.0
# Lucas Nogueira                  Toronto Raptors    92.0        C  23.0
# Jonas Valanciunas               Toronto Raptors    17.0        C  24.0
# Tarik Black                  Los Angeles Lakers    28.0        C  24.0
# Alex Len                           Phoenix Suns    21.0        C  22.0
# Alan Williams                      Phoenix Suns    15.0        C  23.0
# Willie Cauley-Stein            Sacramento Kings     0.0        C  22.0
# ...

# %%
df.columns = ['Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College', 'Salary USD']
df.head()
# Out:
#                          Team  Number Position   Age  Height      Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0  187.48   81.818182
# Jae Crowder    Boston Celtics    99.0       SF  25.0  197.64  106.818182
# John Holland   Boston Celtics    30.0       SG  27.0  195.10   93.181818
# R.J. Hunter    Boston Celtics    28.0       SG  22.0  195.10   84.090909
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0  207.80  105.000000
#
#                          College  Salary USD
# Name
# Avery Bradley              Texas   7730337.0
# Jae Crowder            Marquette   6796117.0
# John Holland   Boston University         NaN
# R.J. Hunter        Georgia State   1148640.0
# Jonas Jerebko                      5000000.0

# %%
df.query(" Height>200 and (Age<25 or Age>35) and Position in ['C','SG'] and `Salary USD`>1_000_000 ")
# Out:
#                                            Team  Number Position   Age  \
# Name
# Jared Sullinger                  Boston Celtics     7.0        C  24.0
# Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# Sergey Karasev                    Brooklyn Nets    10.0       SG  22.0
# Joel Embiid                  Philadelphia 76ers    21.0        C  22.0
# Jahlil Okafor                Philadelphia 76ers     8.0        C  20.0
# Bismack Biyombo                 Toronto Raptors     8.0        C  23.0
# Lucas Nogueira                  Toronto Raptors    92.0        C  23.0
# Jonas Valanciunas               Toronto Raptors    17.0        C  24.0
# Alex Len                           Phoenix Suns    21.0        C  22.0
# Willie Cauley-Stein            Sacramento Kings     0.0        C  22.0
# Andre Drummond                  Detroit Pistons     0.0        C  22.0
# Glenn Robinson III               Indiana Pacers    40.0       SG  22.0
# ...

# %%
# %%timeit -r 10 -n 100
df.query(" Height>200 and (Age<25 or Age>35) and (Position=='C' or Position=='SG') and `Salary USD`>1_000_000 ")
# Out:
# 7.99 ms ± 1.04 ms per loop (mean ± std. dev. of 10 runs, 100 loops each)

# %%
# %%timeit -r 10 -n 100
df.query(" Height>200 and (Age<25 or Age>35) and Position in ['C','SG'] and `Salary USD`>1_000_000 ")
# Out:
# 7.49 ms ± 248 µs per loop (mean ± std. dev. of 10 runs, 100 loops each)

# %%
# %%timeit -r 10 -n 100
df[ (df.Height>200) & ((df.Age<25) | (df.Age>35)) & \
    ((df.Position=='C') | (df.Position=='SG')) & (df["Salary USD"]>1_000_000) ]
# Out:
# 3.15 ms ± 531 µs per loop (mean ± std. dev. of 10 runs, 100 loops each)
