# %%
import pandas as pd

# %%
#df = pd.read_csv("http://51.91.120.89/extras/f500.csv")
df = pd.read_csv(r"C:\Users\kurs\Downloads\f500.csv", comment="#", 
                 usecols=[0,1,4]) #["profits","company","rank"]
# \t \n \r \f
df
# Out:
#                             company  rank  profits
# 0                           Walmart     1  13643.0
# 1                        State Grid     2   9571.3
# 2                     Sinopec Group     3   1257.9
# 3          China National Petroleum     4   1867.5
# 4                      Toyota Motor     5  16899.3
# ..                              ...   ...      ...
# 495  Teva Pharmaceutical Industries   496    329.0
# 496        New China Life Insurance   497    743.9
# 497       Wm. Morrison Supermarkets   498    406.4
# 498                             TUI   499   1151.7
# 499                      AutoNation   500    430.5
#
# [500 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
#        'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
#        'country', 'hq_location', 'website', 'years_on_global_500_list',
#        'employees', 'total_stockholder_equity'],
#       dtype='object')

# %%
df = pd.read_csv(r"C:\Users\kurs\Downloads\f500.csv", comment="#", 
                 usecols=lambda c: c.startswith( ("c","p") ) ) 
df
# Out:
#                             company  profits  profit_change  \
# 0                           Walmart  13643.0           -7.2
# 1                        State Grid   9571.3           -6.2
# 2                     Sinopec Group   1257.9          -65.0
# 3          China National Petroleum   1867.5          -73.7
# 4                      Toyota Motor  16899.3          -12.3
# ..                              ...      ...            ...
# 495  Teva Pharmaceutical Industries    329.0          -79.3
# 496        New China Life Insurance    743.9          -45.6
# 497       Wm. Morrison Supermarkets    406.4           20.4
# 498                             TUI   1151.7          195.5
# 499                      AutoNation    430.5           -2.7
#
#                      ceo  previous_rank  country
# 0    C. Douglas McMillon              1      USA
# 1                Kou Wei              2    China
# 2              Wang Yupu              4    China
# ...

# %%
columns = ['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
       'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
       'country', 'hq_location', 'website', 'years_on_global_500_list',
       'employees', 'total_stockholder_equity']

df = pd.read_csv(r"C:\Users\kurs\Downloads\f500nh.csv", skipinitialspace=True,
                 header=None, names=columns, skiprows=10, nrows=350, 
                 dtype={
                     "rank" : pd.np.int8
                 } )  # prefix="col_", skipfooter=10,
df
# Out:
# C:\Users\kurs\AppData\Local\Temp/ipykernel_1620/2827215317.py:9: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   "rank" : pd.np.int8
#                     company  rank  revenues  revenue_change  profits   assets  \
# 0                  McKesson    11    198533             3.1   5070.0    60969
# 1                        BP    12    186606           -17.4    115.0   263316
# 2        UnitedHealth Group    13    184840            17.7   7017.0   122810
# 3                CVS Health    14    177526            15.8   5317.0    94462
# 4       Samsung Electronics    15    173957            -2.0  19316.5   217104
# ..                      ...   ...       ...             ...      ...      ...
# 345            JFE Holdings   100     30539             6.8    627.0    38920
# 346  Mizuho Financial Group   101     30390            13.5   5570.1  1799736
# ...

# %%
df.dtypes
# Out:
# company                      object
# rank                           int8
# revenues                      int64
# revenue_change              float64
# profits                     float64
# assets                        int64
# profit_change               float64
# ceo                          object
# industry                     object
# sector                       object
# previous_rank                 int64
# country                      object
# hq_location                  object
# website                      object
# years_on_global_500_list      int64
# employees                     int64
# total_stockholder_equity      int64
# dtype: object

# %%
df.describe()
# Out:
#              rank       revenues  revenue_change       profits        assets  \
# count  350.000000     350.000000      348.000000    350.000000  3.500000e+02
# mean    15.077143   61243.831429        4.248563   3310.557714  3.028913e+05
# std     69.763763   32991.977033       30.163052   5275.004729  5.610357e+05
# min   -128.000000   30316.000000      -67.300000 -13038.000000  3.717000e+03
# 25%    -40.750000   37650.000000       -5.500000    744.325000  4.409175e+04
# 50%     28.500000   49441.000000        0.400000   2005.000000  8.794800e+04
# 75%     72.000000   71669.000000        6.800000   4446.700000  2.215458e+05
# max    127.000000  198533.000000      442.300000  41883.900000  3.473238e+06
#
#        profit_change  previous_rank  years_on_global_500_list      employees  \
# count     304.000000     350.000000                350.000000     350.000000
# mean        1.610526     181.557143                 16.385714  141221.362857
# ...

# %%
df.isna().sum()
# Out:
# company                      0
# rank                         0
# revenues                     0
# revenue_change               2
# profits                      0
# assets                       0
# profit_change               46
# ceo                          0
# industry                     0
# sector                       0
# previous_rank                0
# country                      0
# hq_location                  0
# website                      0
# years_on_global_500_list     0
# employees                    0
# total_stockholder_equity     0
# dtype: int64

# %%
columns = ['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
       'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
       'country', 'hq_location', 'website', 'years_on_global_500_list',
       'employees', 'total_stockholder_equity']

df = pd.read_csv(r"C:\Users\kurs\Downloads\f500nh.csv", skipinitialspace=True,
                 header=None, names=columns, converters={
                     "company" : lambda s:s.upper(),
                     "rank" : lambda x: int(x)<=10
                 }
                 ) 
df.head(20)
# Out:
#                      company   rank  revenues  revenue_change  profits  \
# 0                    WALMART   True    485873             0.8  13643.0
# 1                 STATE GRID   True    315199            -4.4   9571.3
# 2              SINOPEC GROUP   True    267518            -9.1   1257.9
# 3   CHINA NATIONAL PETROLEUM   True    262573           -12.3   1867.5
# 4               TOYOTA MOTOR   True    254694             7.7  16899.3
# 5                 VOLKSWAGEN   True    240264             1.5   5937.3
# 6          ROYAL DUTCH SHELL   True    240033           -11.8   4575.0
# 7         BERKSHIRE HATHAWAY   True    223604             6.1  24074.0
# 8                      APPLE   True    215639            -7.7  45687.0
# 9                EXXON MOBIL   True    205004           -16.7   7840.0
# 10                  MCKESSON  False    198533             3.1   5070.0
# 11                        BP  False    186606           -17.4    115.0
# ...

# %%
df.set_index("company", inplace=True)
df
# Out:
#                                  rank  revenues  revenue_change  profits  \
# company
# WALMART                          True    485873             0.8  13643.0
# STATE GRID                       True    315199            -4.4   9571.3
# SINOPEC GROUP                    True    267518            -9.1   1257.9
# CHINA NATIONAL PETROLEUM         True    262573           -12.3   1867.5
# TOYOTA MOTOR                     True    254694             7.7  16899.3
# ...                               ...       ...             ...      ...
# TEVA PHARMACEUTICAL INDUSTRIES  False     21903            11.5    329.0
# NEW CHINA LIFE INSURANCE        False     21796           -13.3    743.9
# WM. MORRISON SUPERMARKETS       False     21741           -11.3    406.4
# TUI                             False     21655            -5.5   1151.7
# AUTONATION                      False     21609             3.6    430.5
#
#                                 assets  profit_change                  ceo  \
# ...

# %%
df.reset_index(inplace=True)

# %%
columns = ['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
       'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
       'country', 'hq_location', 'website', 'years_on_global_500_list',
       'employees', 'total_stockholder_equity']

df = pd.read_csv(r"C:\Users\kurs\Downloads\f500nh.csv", 
                 header=None, names=columns, index_col="company"
                 ) 
df.head(20)
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# company
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
# Volkswagen                   6    240264             1.5   5937.3  432116
# Royal Dutch Shell            7    240033           -11.8   4575.0  411275
# Berkshire Hathaway           8    223604             6.1  24074.0  620854
# Apple                        9    215639            -7.7  45687.0  321686
# Exxon Mobil                 10    205004           -16.7   7840.0  330314
# McKesson                    11    198533             3.1   5070.0   60969
# ...

# %%
df1 = df.sample(frac=.05, random_state=0)
df1.reset_index(inplace=True)
df1
# Out:
#                                 company  rank  revenues  revenue_change  \
# 0                                Uniper    91     74407             NaN
# 1                                 Merck   255     39807             0.8
# 2                              Barclays   284     36789           -25.7
# 3                                Danone   446     24267            -2.4
# 4                 Alibaba Group Holding   462     23517            47.9
# 5                              Glencore    16    173883             2.0
# 6                        SNCF Mobilites   317     33747             3.8
# 7              China General Technology   490     22113           -20.1
# 8                    Marathon Petroleum   160     55858           -13.5
# 9                        Banco Bradesco   154     57443            31.3
# 10              Sumitomo Life Insurance   242     40921            31.6
# 11               China Minsheng Banking   251     40234            -5.2
# ...

# %%
df.to_csv("top500.csv", sep="\t", index=False)

# %% [markdown]
# #### Ładowanie danych z XLS

# %%
df = pd.read_excel("http://51.91.120.89/extras/films.xlsx", sheet_name="COMEDY")
df
# Out:
#     Entry                          Film  \
# 0       1                    Annie Hall
# 1       2                         Borat
# 2       3              Some Like it Hot
# 3       4                  Team America
# 4       5                Dr Strangelove
# 5       5               The Ladykillers
# 6       7                     Duck Soup
# 7       7                      Rushmore
# 8       9        Kind Hearts & Coronets
# 9      10  Monty Python’s Life of Brian
# 10     11                     Airplane!
# 11     12                      Election
# 12     12               His Girl Friday
# 13     12              The Big Lebowski
# 14     15            This Is Spinal Tap
# 15     16              Bringing Up Baby
# 16     17  There’s Something About Mary
# 17     18            Dazed and Confused
# 18     18                          MASH
# 19     20                 Groundhog Day
# 20     21                      Clueless
# 21     22            The Great Dictator
# ...

# %%
df_dict = pd.read_excel(r"C:\Users\kurs\Downloads\films.xlsx", sheet_name=None)

# %%
type(df_dict)
# Out:
# dict

# %%
df_dict.keys()
# Out:
# dict_keys(['ROMANCE', 'CRIME', 'COMEDY', 'ACTION', 'ARTHOUSE AND DRAMA', 'SCI-FI AND FANTASY', 'HORROR'])

# %%
df = df_dict.get("COMEDY")
df
# Out:
#     Entry                          Film  \
# 0       1                    Annie Hall
# 1       2                         Borat
# 2       3              Some Like it Hot
# 3       4                  Team America
# 4       5                Dr Strangelove
# 5       5               The Ladykillers
# 6       7                     Duck Soup
# 7       7                      Rushmore
# 8       9        Kind Hearts & Coronets
# 9      10  Monty Python’s Life of Brian
# 10     11                     Airplane!
# 11     12                      Election
# 12     12               His Girl Friday
# 13     12              The Big Lebowski
# 14     15            This Is Spinal Tap
# 15     16              Bringing Up Baby
# 16     17  There’s Something About Mary
# 17     18            Dazed and Confused
# 18     18                          MASH
# 19     20                 Groundhog Day
# 20     21                      Clueless
# 21     22            The Great Dictator
# ...

# %%
df.to_excel("comedy.xlsx", sheet_name="Komedie", index=False)
