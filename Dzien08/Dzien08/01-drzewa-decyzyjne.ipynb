# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %%
df =pd.read_csv("http://51.91.120.89/extras/iris.csv")
df
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df["class"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
df["class_value"] = df["class"].map({
    "Iris-setosa":0, "Iris-versicolor":1, "Iris-virginica":2
})
df
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class  \
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
#      class_value
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 145            2
# 146            2
# 147            2
# 148            2
# 149            2
#
# [150 rows x 6 columns]

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=df, x="sepallength", y="sepalwidth", hue="class")
# Out:
# <AxesSubplot:xlabel='sepallength', ylabel='sepalwidth'>

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=df, x="petallength", y="petalwidth", hue="class")
# Out:
# <AxesSubplot:xlabel='petallength', ylabel='petalwidth'>

# %%
df.columns
# Out:
# Index(['sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'class',
#        'class_value'],
#       dtype='object')

# %%
sns.heatmap( df.iloc[: , :4].corr() , annot=True)
# Out:
# <AxesSubplot:>

# %%
# !pip install mlxtend
# !pip install dtreeplt
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
# Requirement already satisfied: setuptools in c:\users\kurs\anaconda3\lib\site-packages (from mlxtend) (58.0.4)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\kurs\anaconda3\lib\site-packages (from mlxtend) (1.20.3)
# Requirement already satisfied: scikit-learn>=0.20.3 in c:\users\kurs\anaconda3\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\kurs\anaconda3\lib\site-packages (from mlxtend) (1.7.1)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\kurs\anaconda3\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\kurs\anaconda3\lib\site-packages (from mlxtend) (3.4.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\kurs\anaconda3\lib\site-packages (from mlxtend) (1.3.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kurs\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kurs\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kurs\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kurs\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kurs\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: six in c:\users\kurs\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\kurs\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2021.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kurs\anaconda3\lib\site-packages (from scikit-learn>=0.20.3->mlxtend) (2.2.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.19.0
# Collecting dtreeplt
#   Downloading dtreeplt-0.1.43-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: scikit-learn>=0.20.2 in c:\users\kurs\anaconda3\lib\site-packages (from dtreeplt) (1.1.0)
# Requirement already satisfied: numpy>=1.15.1 in c:\users\kurs\anaconda3\lib\site-packages (from dtreeplt) (1.20.3)
# Requirement already satisfied: matplotlib>=3.0.2 in c:\users\kurs\anaconda3\lib\site-packages (from dtreeplt) (3.4.3)
# Requirement already satisfied: ipywidgets>=7.4.2 in c:\users\kurs\anaconda3\lib\site-packages (from dtreeplt) (7.6.5)
# Requirement already satisfied: ipython>=7.2.0 in c:\users\kurs\anaconda3\lib\site-packages (from dtreeplt) (7.29.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\kurs\anaconda3\lib\site-packages (from ipython>=7.2.0->dtreeplt) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\kurs\anaconda3\lib\site-packages (from ipython>=7.2.0->dtreeplt) (0.18.0)
# Requirement already satisfied: matplotlib-inline in c:\users\kurs\anaconda3\lib\site-packages (from ipython>=7.2.0->dtreeplt) (0.1.2)
# Requirement already satisfied: pickleshare in c:\users\kurs\anaconda3\lib\site-packages (from ipython>=7.2.0->dtreeplt) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\kurs\anaconda3\lib\site-packages (from ipython>=7.2.0->dtreeplt) (3.0.20)
# Requirement already satisfied: pygments in c:\users\kurs\anaconda3\lib\site-packages (from ipython>=7.2.0->dtreeplt) (2.10.0)
# Requirement already satisfied: backcall in c:\users\kurs\anaconda3\lib\site-packages (from ipython>=7.2.0->dtreeplt) (0.2.0)
# Requirement already satisfied: decorator in c:\users\kurs\anaconda3\lib\site-packages (from ipython>=7.2.0->dtreeplt) (5.1.0)
# Requirement already satisfied: colorama in c:\users\kurs\anaconda3\lib\site-packages (from ipython>=7.2.0->dtreeplt) (0.4.4)
# Requirement already satisfied: setuptools>=18.5 in c:\users\kurs\anaconda3\lib\site-packages (from ipython>=7.2.0->dtreeplt) (58.0.4)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\kurs\anaconda3\lib\site-packages (from ipywidgets>=7.4.2->dtreeplt) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\kurs\anaconda3\lib\site-packages (from ipywidgets>=7.4.2->dtreeplt) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\kurs\anaconda3\lib\site-packages (from ipywidgets>=7.4.2->dtreeplt) (6.4.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\kurs\anaconda3\lib\site-packages (from ipywidgets>=7.4.2->dtreeplt) (3.5.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\kurs\anaconda3\lib\site-packages (from ipywidgets>=7.4.2->dtreeplt) (0.2.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\kurs\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.4.2->dtreeplt) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\kurs\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.4.2->dtreeplt) (6.1.12)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\kurs\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.4.2->dtreeplt) (1.4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\kurs\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.2.0->dtreeplt) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\kurs\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.4.2->dtreeplt) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\kurs\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.4.2->dtreeplt) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\kurs\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.4.2->dtreeplt) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\kurs\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.4.2->dtreeplt) (228)
# Requirement already satisfied: cycler>=0.10 in c:\users\kurs\anaconda3\lib\site-packages (from matplotlib>=3.0.2->dtreeplt) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kurs\anaconda3\lib\site-packages (from matplotlib>=3.0.2->dtreeplt) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kurs\anaconda3\lib\site-packages (from matplotlib>=3.0.2->dtreeplt) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kurs\anaconda3\lib\site-packages (from matplotlib>=3.0.2->dtreeplt) (1.3.1)
# Requirement already satisfied: six in c:\users\kurs\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.0.2->dtreeplt) (1.16.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\kurs\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.4.2->dtreeplt) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\kurs\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.4.2->dtreeplt) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\kurs\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.4.2->dtreeplt) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\kurs\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.2.0->dtreeplt) (0.2.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\kurs\anaconda3\lib\site-packages (from scikit-learn>=0.20.2->dtreeplt) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kurs\anaconda3\lib\site-packages (from scikit-learn>=0.20.2->dtreeplt) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\kurs\anaconda3\lib\site-packages (from scikit-learn>=0.20.2->dtreeplt) (1.1.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\kurs\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (6.4.5)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\kurs\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (1.8.0)
# Requirement already satisfied: nbconvert in c:\users\kurs\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (6.1.0)
# Requirement already satisfied: jinja2 in c:\users\kurs\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (2.11.3)
# Requirement already satisfied: argon2-cffi in c:\users\kurs\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\kurs\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\kurs\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (0.11.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\kurs\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\kurs\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\kurs\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\kurs\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (1.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\kurs\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\kurs\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\kurs\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (0.3)
# Requirement already satisfied: bleach in c:\users\kurs\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (4.0.0)
# Requirement already satisfied: defusedxml in c:\users\kurs\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\kurs\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (0.5.3)
# Requirement already satisfied: testpath in c:\users\kurs\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\kurs\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (1.4.3)
# Requirement already satisfied: async-generator in c:\users\kurs\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\kurs\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (1.5.1)
# Requirement already satisfied: packaging in c:\users\kurs\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (21.0)
# Requirement already satisfied: webencodings in c:\users\kurs\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.4.2->dtreeplt) (0.5.1)
# Installing collected packages: dtreeplt
# Successfully installed dtreeplt-0.1.43

# %%
from sklearn.tree import DecisionTreeClassifier
from mlxtend.plotting import plot_decision_regions
from dtreeplt import dtreeplt

# %%
#X = df[ ["sepallength","sepalwidth"] ]
X = df[ ["petallength","petalwidth"] ]
y = df.class_value

# %%
model = DecisionTreeClassifier(max_depth=11)
model.fit(X, y)
model.score(X, y)
# Out:
# 0.9933333333333333

# %%
plt.figure(figsize=(7,7))
plot_decision_regions(X.values, y.values, model)
# Out:
# C:\Users\kurs\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,12))
dtreeplt(model, feature_names=X.columns, target_names=["setosa","versicolor","virginica"]).view();
plt.savefig("dt.png", dpi=150)
# Out:
# C:\Users\kurs\anaconda3\lib\site-packages\dtreeplt\dtreeplt.py:256: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax.annotate(s='', xy=(dx, dy), xytext=(x, y),

# %%
X = df.iloc[:, :4]
y = df.class_value

model = DecisionTreeClassifier(max_depth=5, random_state=0)
model.fit(X, y)
model.score(X, y)
# Out:
# 1.0

# %%
pd.DataFrame( model.feature_importances_ , X.columns)
# Out:
#                     0
# sepallength  0.000000
# sepalwidth   0.013333
# petallength  0.064056
# petalwidth   0.922611

# %%
plt.figure(figsize=(12,8))
dtreeplt(model, feature_names=X.columns, target_names=["setosa","versicolor","virginica"]).view();
# Out:
# C:\Users\kurs\anaconda3\lib\site-packages\dtreeplt\dtreeplt.py:256: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax.annotate(s='', xy=(dx, dy), xytext=(x, y),
