# %%
import pandas as pd
import sqlalchemy

# %%
# !pip install psycopg2

# %%
import psycopg2

# %%
# connection string
cs = "postgresql+psycopg2://elanco_user:elanco_pass@51.91.120.89:5432/elanco"

# %%
# tworzymy "rurę" do bazy danych
db_link = sqlalchemy.create_engine(cs)
db_link
# Out:
# Engine(postgresql+psycopg2://elanco_user:***@51.91.120.89:5432/elanco)

# %%
df = pd.read_sql_table("city", db_link)
df
# Out:
#      city_id                 city  country_id                last_update
# 0          1   A Corua (La Corua)          87 2006-02-15 09:45:25.000000
# 1          2                 Abha          82 2006-02-15 09:45:25.000000
# 2          3            Abu Dhabi         101 2006-02-15 09:45:25.000000
# 3          4                 Acua          60 2006-02-15 09:45:25.000000
# 4          5                Adana          97 2006-02-15 09:45:25.000000
# ..       ...                  ...         ...                        ...
# 611      632              Baku2AA          10 2021-05-25 16:57:35.800783
# 612      627  Chrząszczyżewoszyce          76 2021-05-25 16:57:38.623808
# 613      629  Chrząszczyżewoszyce          76 2021-05-25 16:57:38.623808
# 614      633  Chrząszczyżewoszyce          76 2021-05-25 16:57:38.623808
# 615      645            Marianowo          15 2021-09-27 15:26:03.255701
#
# [616 rows x 4 columns]

# %%
df = pd.read_sql("SELECT * FROM city WHERE city_id>600 ", db_link)
df
# Out:
#     city_id                 city  country_id                last_update
# 0       609          San Escobar          32 2020-10-08 10:01:58.416045
# 1       610          Nibylandia2          15 2020-10-08 10:09:05.490605
# 2       616          San Escobar          32 2020-10-08 10:08:18.071989
# 3       617          Nibylandia2          15 2020-10-08 10:09:05.490605
# 4       618          Nibylandia2          15 2020-10-08 10:09:05.490605
# 5       619          San Escobar          32 2020-10-08 10:10:28.366308
# 6       621          San Escobar          32 2020-10-08 10:15:01.531884
# 7       622          San Escobar          32 2020-10-08 10:15:21.265922
# 8       624        Nibylandia-MW          15 2021-05-25 15:33:32.213793
# 9       627  Chrząszczyżewoszyce          76 2021-05-25 16:57:38.623808
# 10      629  Chrząszczyżewoszyce          76 2021-05-25 16:57:38.623808
# 11      630              Baku2AA          10 2021-05-25 16:54:38.271575
# ...

# %%
pd.read_sql(" INSERT INTO city (city, country_id) VALUES ('XYZ123-MW', 10) ", db_link)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8152/505760981.py in <module>
# ----> 1 pd.read_sql(" INSERT INTO city (city, country_id) VALUES ('XYZ123-MW', 10) ", db_link)
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     626         )
#     627     else:
# --> 628         return pandas_sql.read_query(
#     629             sql,
#     630             index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1591             )
#    1592         else:
# -> 1593             data = result.fetchall()
#    1594             frame = _wrap_result(
#    1595                 data,
#
# ...

# %%
df = pd.read_sql("SELECT * FROM city WHERE city_id>600 ", db_link)
df
# Out:
#     city_id                 city  country_id                last_update
# 0       609          San Escobar          32 2020-10-08 10:01:58.416045
# 1       610          Nibylandia2          15 2020-10-08 10:09:05.490605
# 2       616          San Escobar          32 2020-10-08 10:08:18.071989
# 3       617          Nibylandia2          15 2020-10-08 10:09:05.490605
# 4       618          Nibylandia2          15 2020-10-08 10:09:05.490605
# 5       619          San Escobar          32 2020-10-08 10:10:28.366308
# 6       621          San Escobar          32 2020-10-08 10:15:01.531884
# 7       622          San Escobar          32 2020-10-08 10:15:21.265922
# 8       624        Nibylandia-MW          15 2021-05-25 15:33:32.213793
# 9       627  Chrząszczyżewoszyce          76 2021-05-25 16:57:38.623808
# 10      629  Chrząszczyżewoszyce          76 2021-05-25 16:57:38.623808
# 11      630              Baku2AA          10 2021-05-25 16:54:38.271575
# ...

# %%
df.to_sql("city_20220423_marwit", db_link)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8152/3043918027.py in <module>
# ----> 1 df.to_sql("city_20220423_marwit", db_link)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ...
